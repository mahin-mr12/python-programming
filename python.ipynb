# %% [markdown]
# ## Dynamic Types in Python
#
# python as a script or language is what "dynamically typed", meaning the variable are declared
# during runtime and there datatype is npt explicity satisfied

# %%
a = 10
b = 30
print (a+b)
# Out:
# 40

# %%
a = 20
print(type(a))
a = 20/100
print(type(a))
a = "Text"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## what is the command to check the data type?
#
# type() : Gives the data type of the variable currently in UserWarning

# %% [markdown]
# ## What are immutable data types()

# %% [markdown]
# The datatypes where vale cannot be change once assigned.
#
# Immutable datatypes
# 1 --> Integer (int)
#
# 2 --> floating point (float)
#
# 3 --> boolean (bool)
#
# 4 --> string (str)
#
# 5 --> frozenset
#
# 6 --> tuples (tup)

# %%
a="abcd"
print(a)
a="a7cd"
print(a)
# Out:
# abcd
# a7cd

# %% [markdown]
# ## what is tuple?

# %%
a =(2,3)
print(a)
a =[2,3]
print(a)
