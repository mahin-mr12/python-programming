# %% [markdown]
# please explain in simple pseudo code how upper() function is not a function but a method of str class? (10 marks)

# %%
faculty_names = ["Dr V Maths", "Dr H Maths", "Md K SS", "HH K Maths"]

# %%
for each in faculty_names:
    if each.endswith("Maths") == True:
        print(each)
# Out:
# Dr V Maths
# Dr H Maths
# HH K Maths

# %%
for each in faculty_names:
    if (each.startswith("Dr")!= True) and (each.endswith("Maths")==True):
        print(each)
# Out:
# HH K Maths

# %%
for each in faculty_names:
    if not each.startswith("Dr") and each.endswith("Maths"):
        print(each)
# Out:
# HH K Maths
